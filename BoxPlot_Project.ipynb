# %% [markdown]
# ## Fundamentals of Data Analysis
# ### Box Plot Project

# %%
# Import library and dataset to be used in project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show
import seaborn as sns
from IPython.display import Image
df = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv") # Iris dataset

# %%
Image("BoxPlot.png", width=700, height=1500)

# %% [markdown]
# ### What is a Boxplot?
#
# For some datasets, additional information that measures of cntral tendancy like median, mean and mode is required. Analysts  need to know how data is dispersed. A boxplot is a method of displaying the distribution of data based on a five summay numbers
#     - Minimum (excluding outliers)
#     - First Quartile Q1 (the 25th Percentile) middle value between the smallest number (not min) and the median of dataset.
#     - Median Q2 (50th Percentile) This is the middle of the dataset.
#     - Third quartile Q3 (the 75th Percentile) middle value between the median and the highest value (not max).
#     - Maximum (excluding outliers)
# The interquartile range (IQR) lies between the 25th and the 75th percentile. A Boxplot is constructed by drawing a box between the upper and lower quartiles, drawing a solid line across the box to locate the median. Boxplots can highlight outliers (shown as green circles in above image) and are very good at showing how data is spread out. They have an advantage over other plot types such as histograms of taking up less space. This is useful when you want to compare data from two columns of a DataFrame.
#
# ***

# %% [markdown]
# ### Quartile
#
# To find the lower quartile, we find all the values lower than the median. The lower quartile is the median of these values. The upper quartile is found by taking all the values higher than the median and then taking the median of the upper set of values.

# %% [markdown]
# ### Percentile
#
#  Interpreting Percentiles, Quartiles, and Median
# A percentile indicates the relative standing of a data value when data are sorted into numerical order from smallest to largest. Percentages of data values are less than or equal to the pth percentile. For example, 15% of data values are less than or equal to the 15th percentile.
# Low percentiles always correspond to lower data values.
# High percentiles always correspond to higher data values.
# A percentile may or may not correspond to a value judgment about whether it is “good” or “bad.” The interpretation of whether a certain percentile is “good” or “bad” depends on the context of the situation to which the data applies. In some situations, a low percentile would be considered “good;” in other contexts a high percentile might be considered “good”. In many situations, there is no value judgment that applies.
# Understanding how to interpret percentiles properly is important not only when describing data, but also when calculating probabilities in later chapters of this text.
# ***

# %% [markdown]
# ### Outlier
#
# An outlier is an observation that lies an abnormal distance from other 'normal' values. The analyst decides which values are classified as normal before abnormal observations can be identified.(1)The following quantities (called fences) are needed for identifying extreme values in the tails of the distribution:
#     - lower inner fence: Q1 - 1.5*IQ
#     - upper inner fence: Q3 + 1.5*IQ
#     - lower outer fence: Q1 - 3*IQ
#      -upper outer fence: Q3 + 3*IQ
# Outlier detection criteria
# A point beyond an inner fence on either side is considered a mild outlier. A point beyond an outer fence is considered an extreme outlier. I have referred to this (1) onlie information because it is well defined and easily explaind in a project setting.

# %%
Image("iris_boxplots.png", width=700, height=1500)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
#  #### Commentry
#  Recall that the mean is impacted by especially large or small values, even if there are just a few of them, while the median is more stable with respect to exceptional values.
#  Therefore:
# If the distribution is normal, there are few exceptionally large or small values. The mean will be about the same as the median, and the box plot will look symmetric.
# If the distribution is skewed to the right most values are 'small', but there are a few exceptionally large ones. Those exceptional values will impact the mean and pull it to the right, so that the mean will be greater than the median. The box plot will look as if the box was shifted to the left so that the right tail will be longer, and the median will be closer to the left line of the box in the box plot.
# If the distribution is skewed to the left, most values are 'large', but there are a few exceptionally small ones. Those exceptional values will impact the mean and pull it to the left, so that the mean will be less than the median. The box plot will look as if the box was shifted to the right so that the left tail will be longer, and the median will be closer to the right line of the box in the box plot.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Boxplot - Sepal Length
#
# For the Iris data set Sepal Length values, the mean (5.843) is greater than the median (5.8). This is shown in the Boxplot diagram blow, where
#
# ***

# %%
from matplotlib import rcParams
sns.boxplot(data=df.sepal_length, orient="h").set_title('Iris Data - Sepal Length Boxplot') # horizontal boxplot
sns.set(rc={'figure.figsize':(18,2)})
plt.grid(True)

# %%
sns.distplot(df.sepal_length, color="r").set_title('Iris Data - Sepal Length Distplot')
# Out:
# C:\Users\eamonn\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Iris Data - Sepal Length Distplot')

# %%
sns.kdeplot(df.sepal_length, shade=True, color="y").set_title('Iris Data - Sepal Length Kdeplot');
sns.rugplot(df.sepal_length);

# %% [markdown]
# ### Boxplot - Sepal Width
#
# This is a new description

# %%
from matplotlib import rcParams
sns.boxplot(data=df.sepal_width, orient="h").set_title('Iris Data - Sepal Width Boxplot') # horizontal boxplot
plt.grid(True)

# %%
sns.distplot(df.sepal_width, color="r").set_title('Iris Data - Sepal Width Distplot')
# Out:
# C:\Users\eamonn\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Iris Data - Sepal Width Distplot')

# %%
sns.kdeplot(df.sepal_width, shade=True, color="y").set_title('Iris Data - Sepal Width Kdeplot');
sns.rugplot(df.sepal_width);

# %% [markdown]
# ### Boxplot - Petal Length
#
# Bla de blah

# %%
from matplotlib import rcParams
sns.boxplot(data=df.petal_length, orient="h").set_title('Iris Data - Petal Length Boxplot') # horizontal boxplot
plt.grid(True)

# %%
sns.distplot(df.petal_length, color="r").set_title('Iris Data - Petal Length Distplot')
# Out:
# C:\Users\eamonn\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Iris Data - Petal Length Distplot')

# %%
sns.kdeplot(df.petal_length, shade=True, color="y").set_title('Iris Data - Petal Length Kdeplot');
sns.rugplot(df.petal_length);

# %% [markdown]
# ### Boxplot - Petal Width
#
# Bla de blah

# %%
from matplotlib import rcParams
sns.boxplot(data=df.petal_width, orient="h").set_title('Iris Data - Petal Width Boxplot') # horizontal boxplot
plt.grid(True)

# %%
sns.distplot(df.petal_width, color="r").set_title('Iris Data - Petal Width Distplot')
# Out:
# C:\Users\eamonn\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Iris Data - Petal Width Distplot')

# %%
sns.kdeplot(df.petal_width, shade=True, color="y").set_title('Iris Data - Petal Width Kdeplot');
sns.rugplot(df.petal_width);

# %%
sns.pairplot(df, hue='species')

# %% [markdown]
# ### Advantages
# Although Box Plots may seem primitive in comparison to a Histogram or Density Plot, they have the advantage of taking up less space, which is useful when comparing distributions between many groups or datasets.
# Here are the types of observations one can make from viewing a Box Plot:
# What the key values are, such as: the average, median 25th percentile etc.
# If there are any outliers and what their values are.
# Is the data symmetrical.
# How tightly is the data grouped.
# If the data is skewed and if so, in what direction.

# %%
Image("boxnorm.png", width=400, height=1200)

# %% [markdown]
# #### For image above!!!
# https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51

# %% [markdown]
# ### Compare Box Plot with alternatives

# %% [markdown]
# #### Boxplot Vs Histogram
# A histogram is a type of bar chart that graphically displays the frequencies of a data set. The only difference between a histogram and a bar chart is that a histogram displays frequencies for a group of data, rather than an individual data point; therefore, no spaces are present between the bars.

# %%
#df.hist(column=['Nat'])
hist = df.hist(bins=10)

# %% [markdown]
# ### Boxplot vs swarmplot!!!!!!

# %%
import seaborn as sns
from matplotlib import rcParams 
# usual boxplot
ax = sns.boxplot(data=df)
ax = sns.swarmplot(data=df)
rcParams['figure.figsize'] = 8,20
# Add transparency to colors
for patch in ax.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor((r, g, b, .5))
    
plt.grid(True)

# %%
#df.boxplot(column=['Nat','Gal'])

# %% [markdown]
# #### Boxplot Vs Scatterplot
#
# Scatter Plots
# Scatter plots are similar to line graphs in that they use horizontal and vertical axes to plot data points. However, they have a very specific purpose. Scatter plots show how much one variable is affected by another. The relationship between two variables is called their correlation .
# Scatter plots usually consist of a large body of data. The closer the data points come when plotted to making a straight line, the higher the correlation between the two variables, or the stronger the relationship.
# If the data points make a straight line going from the origin out to high x- and y-values, then the variables are said to have a positive correlation . If the line goes from a high-value on the y-axis down to a high-value on the x-axis, the variables have a negative correlation .
#
# A perfect positive correlation is given the value of 1. A perfect negative correlation is given the value of -1. If there is absolutely no correlation present the value given is 0. The closer the number is to 1 or -1, the stronger the correlation, or the stronger the relationship between the variables. The closer the number is to 0, the weaker the correlation. So something that seems to kind of correlate in a positive direction might have a value of 0.67, whereas something with an extremely weak negative correlation might have the value -.21.

# %%
import matplotlib.pyplot as plt
import pandas
colors = ['red','green']

#plt.scatter(x=df['Oth'], y=df['Nat'], color=colors)

# %%
plt.scatter(x=df['petal_length'], y=df['petal_width'], color=colors)
sns.set(rc={'figure.figsize':(4,12)})

# %% [markdown]
# Boxplot Vs Line Plot

# %%
df.plot.line(figsize=(12,8), grid=True)

# %%
#df.plot(x='When', y=['Nat','Dub', 'Gal'], figsize=(10,5), grid=True)

# %%
from matplotlib import pyplot
import seaborn

import mylib

a4_dims = (11.7, 8.27)
df = mylib.load_data()
fig, ax = pyplot.subplots(figsize=a4_dims)
seaborn.violinplot(ax=ax, data=df, **violin_options)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-55677726eb81> in <module>()
#       2 import seaborn
#       3
# ----> 4 import mylib
#       5
#       6 a4_dims = (11.7, 8.27)
#
# ModuleNotFoundError: No module named 'mylib'

# %% [markdown]
# ### Compare Boxplot and Violin Plot

# %%
sns.barplot('Nat', 'When', data = df.loc[0:150:8])

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(14,10))

# Get the means of each group
means = df[["Nat", "Dub", "Cork", "Gal", "Lim", "Oth"]].mean(axis=0).astype(int)

# Generate some mock x coordinates
x = np.arange(len(means))

# Makes a line plot of the means of each group
ax[0][0].plot(x, means)

# Makes a scatter plot of the means of each group
ax[0][1].scatter(x, means)

# Makes a bar plot of the means of each group
ax[1][0].bar(x, means)

# Makes a boxplot of the data values in each group
ax[1][1].boxplot(means)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16b08f16d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16b08f166d8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16b08f16160>],
#  'medians': [<matplotlib.lines.Line2D at 0x16b08ee9a20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16b08ee9908>],
#  'means': []}

# %%
sns.violinplot(x='species', y='petal_width', data=df) 
sns.set(rc={'figure.figsize':(5,8)})

# %%
#g = sns.FacetGrid(df.loc[90:110:4], col="Year",  hue="Year", col_wrap=2, size=5.5)
#g = (g.map(plt.scatter, "Year", "Oth", edgecolor="w") .add_legend())
#sns.violinplot(x='Nat_Mean', y='Gal', data=df.loc[0:150:4],  orient='v' , ax=ax1)
#sns.violinplot(x='Nat_Mean', y='Gal', data=df.loc[1:150:4] ,  orient='v' , ax=ax2)

# %%
 #Q1 data for each year
#sns.violinplot(x='Nat_Mean', y='Gal', data=df.loc[0:150:4]) 

sns.violinplot(x="species", y="petal_width",  palette={"blue","red","yellow"}, data=df, )
plt.show()

# %%
sns.FacetGrid(df, hue="species", size=5).map(sns.kdeplot, "petal_length").add_legend() # seaborne kde plot
plt.show()

# %%
#In Pandas use Andrews Curves to plot and visualize data structure.
#Each multivariate observation is transformed into a curve and represents the coefficients of a Fourier series.
#This useful for detecting outliers in times series data.
#Use colormap to change the color of the curves

from pandas.tools.plotting import andrews_curves
andrews_curves(df, "species",colormap='rainbow')
plt.show()
# Out:
# C:\Users\eamonn\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: 'pandas.tools.plotting.andrews_curves' is deprecated, import 'pandas.plotting.andrews_curves' instead.
#   import sys

# %%
# Use Pandas' radviz to plot features on a 2D plane'
#Each sample is attached to each point using dimensional anchors,
#weighted by the relative value for that feature. 
#I also modified the colors in this representation
from pandas.tools.plotting import radviz
radviz(df, "species",colormap='autumn')
plt.show()
# Out:
# C:\Users\eamonn\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: 'pandas.tools.plotting.radviz' is deprecated, import 'pandas.plotting.radviz' instead.

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(data=df, hue='species', vars=['sepal_length', 'sepal_width'], size = 4)

# %%
plt.subplot(1,2,1)
sns.swarmplot('Nat', 'Gal', data = df.loc[2:6, ['Nat', 'Oth']]

plt.subplot(1,2,2)
sns.boxplot('Nat', 'Gal', data = df.loc[2:6, ['Nat', 'Oth']]
            
            sns.boxplot(  y="b", x= "a", data=df,  orient='v' , ax=axes[0])
sns.boxplot(  y="c", x= "a", data=df,  orient='v' , ax=axes[1])
            
            
f = plt.figure(figsize=(10,3))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
# Out:
#   File "<ipython-input-149-61507d632469>", line 4
#     plt.subplot(1,2,2)
#       ^
# SyntaxError: invalid syntax

# %%
f, (ax1, ax2) = plt.subplots(2)
sns.regplot(, y, ax=ax1)
sns.kdeplot(x, ax=ax2)

# %%
# Set figsize here
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12,5))

# if you didn't set the figsize above you can do the following
# fig.set_size_inches(12, 5)

# flatten axes for easy iterating
for i, ax in enumerate(axes.flatten()):
    sns.boxplot(x= data.iloc[:, i],  orient='v' , ax=ax)

fig.tight_layout()

# %%
f, (ax1, ax2) = plt.subplots(2)

sns.swarmplot(y='petal_length', x='petal_width', data = df,  orient='v' , ax=ax1)
sns.boxplot(y='petal_length', x='petal_width', data = df ,  orient='v' , ax=ax2)
sns.set(rc={'figure.figsize':(10,8)})

# %%
sns.lmplot(x='petal_length', y='petal_width', data=df,
           fit_reg=False, # No regression line
           hue='species')   # Color by evolution stage

# %% [markdown]
# ***
# 1. Outliers https://www.itl.nist.gov/div898/handbook/prc/section1/prc16.htm
#
#
# ***
